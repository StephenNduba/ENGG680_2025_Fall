# %% [markdown]
# # **ENGG680 - Introduction to Digital Engineering**
# ## *Lab Assignment 1: Using Git and Python for Collaborative Coding in Google Colab & Least Square Application*
# ### (100 Marks)

# %% [markdown]
# ## Preliminary: Certificate of Work
# ### (5 Marks)

# %% [markdown]
# *We, the undersigned, certify that this is our own work, which has been done expressly for this course, either without the assistance of any other party or where appropriate we have acknowledged the work of others. Further, we have read and understood the section in the university calendar on plagiarism/cheating/other academic misconduct and we are aware of the implications thereof. We request that the total mark for this assignment be distributed as follows among group members:*

# %% [markdown]
# |          | First Name | Last Name | Signature (Full Name, Date) | Hours | Contribution % |
# |----------|------------|-----------|-----------------------------|-------|----------------|
# | Member 1: | Bright  | Odogwu    | Bright Odogwu | Hours | Contribution |
# | Member 2: | Naomy   | Lafond    | Naomy Lafond | Hours | Contribution |
# | Member 3: | Opeyemi | Arogunmasa| Opeyemi Arogunmasa | Hours | Contribution |
# | Member 4: | Stephen | Nduba     | Stephen Nduba | Hours | Contribution |

# %% [markdown]
# ## Part 1: Printing to the Console
# ### (4 Marks)

# %%
# In the space below, please print "Hello, World! Welcome to the Student Gradebook Management System."
print("Hello, World! Welcome to the Student Gradebook Management System.")
# Out:
# Hello, World! Welcome to the Student Gradebook Management System.

# %%
# Fill in your information using the defined variables below:
# (1 mark)
lab_group_number = 8
intake_year = 2025
intake_semester = "Fall" #"Fall" or "Winter"

# Using f-strings and the variables above, print "This is implemented by Group <lab_group_number>, for ENGG680 <intake_semester> of <intake_year>"
# (1 marks)

print(f"This is implemented by Group {lab_group_number}, for ENGG680 {intake_semester} of {intake_year}")
# Out:
# This is implemented by Group 8, for ENGG680 Fall of 2025

# %%
# Similarly, create variables for each of your group members (eg. member_1, member_2....) and assign them your first names.
# Then, using f-strings and the variables above, print the following sentence:
# "Our Group Members include <member_1>, <member_2>, ..."
# (1 marks)
member_1 = "Stephen"
member_2 = "Naomy"
member_3 = "Bright"
member_4 = "Opeyemi"
print(f"Our Group Members include {member_1}, {member_2}, {member_3}, and {member_4}")
# Out:
# Our Group Members include Stephen, Naomy, Bright, and Opeyemi

# %%
# Use indexing to print "The subjects involved in this grading system is English and Math." using "subjects" below.
# (1 marks)
subjects = ("English", "Math")
print(f"The subjects involved in this grading system is {subjects[0]} and {subjects[1]}.")
# Out:
# The subjects involved in this grading system is English and Math.

# %% [markdown]
# ## Part 2: Python Fundamentals
# ### (11 Marks)

# %%
# Lists (2 marks)

# 1. Create a list of any 5 cities in Alberta.
list_cities = ["Calgary", "Edmonton", "Red Deer", "Lethbridge", "Airdrie"]


# 2. Print the list
print(list_cities)

# 3. Add a new city to list.
list_cities.append("Jasper")

# 4. Remove the second city using either remove() or pop().
list_cities.remove("Edmonton")

# 5. Sort the list alphabetically
final_list = sorted(list_cities)
# 6. Print your final list
print(final_list)
# Out:
# ['Calgary', 'Edmonton', 'Red Deer', 'Lethbridge', 'Airdrie']
# ['Airdrie', 'Calgary', 'Jasper', 'Lethbridge', 'Red Deer']

# %%
from typing_extensions import TypeAlias
# Tuples (2 marks)

# 1. Create a tuple of 3 favorite numbers.
favorite_digits = (1.3, 2, 15)

# 2. Print the tuple.
print(favorite_digits)


# 3. Try to modify the second element. Does that work? Explain.
try:
  favorite_digits[0] = 100
  print(favorite_digits)
except TypeError as e:
  print("No, it does'nt work. Tupples are immutable:", e)
# Out:
# (1.3, 2, 15)
# No, it does'nt work. Tupples are immutable: 'tuple' object does not support item assignment

# %%
# Dictionaries (2 marks)

# 1. Create a dictionary representing a mini visa form with keys like:
# "Name", "File Number", "Country", "Visa Type", "Expiry Year"
visa_form = {"Name": "Stephen", "Country": "Nigeria", "Visa Type": "Study", "Expiry": 2027}
# Assign fictional values to the keys.
# Note: Dictionaries can contain values of different data types.
#

# 2. Print the dictionary
print(visa_form)
#

# 3. Add a new key "University" with a value
visa_form["University"] = "University of Calgary"
#

# 4. Update "Expiry Year" to a new year
visa_form["Expiry"] = [2030]
#

# 5. Print the final dictionary
print(visa_form)
#
# Out:
# {'Name': 'Stephen', 'Country': 'Nigeria', 'Visa Type': 'Study', 'Expiry': 2027}
# {'Name': 'Stephen', 'Country': 'Nigeria', 'Visa Type': 'Study', 'Expiry': [2030], 'University': 'University of Calgary'}

# %%
# Sets (2 marks)

# Set 1
subjects1 = {"Math", "English", "Physics", "Biology", "History"}

# Set 2
subjects2 = {"Math", "English", "Chemistry", "Geography", "Physics"}

# Tip: Use f-strings to print clear messages along with your output.
# Eg. "Union: ", "Intersection: "

# 1. Print both the sets
#
print(subjects1)
print(subjects2)

# 2. Print the union of sets
#
print(f"Union: ", subjects1 | subjects2)

# 3. Print the intersection of sets
#
print(f"Intersection: ", subjects1 ^ subjects2)
# 4. Print the difference (subjects1 - subjects2)
#
print(f"Difference: ", subjects1 - subjects2)
# Out:
# {'Physics', 'Math', 'Biology', 'English', 'History'}
# {'Physics', 'Math', 'English', 'Geography', 'Chemistry'}
# Union:  {'English', 'Geography', 'Chemistry', 'Physics', 'Math', 'Biology', 'History'}
# Intersection:  {'Biology', 'History', 'Geography', 'Chemistry'}
# Difference:  {'History', 'Biology'}

# %%
# Classes and Function (3 marks)

# Step 1: Create a class BankAccount.
class BankAccount:
  # Add class attribute bankname="Canada Bank"
  bankname = "Canada Bank"
  # Add 2 instance attributes: account_holder (string) & balance (float, default value 0.0)
  def __init__ (self, account_holder, balance = 0.0):
    self.account_holder = account_holder
    self.balance = balance
  # Step 2: Add methods
  # 1. deposit(amount) -> Add amount to the balance
  def deposit(self, ammount):
    self.balance += ammount

  # 2. withdraw(amount) -> Subtract the amount if balance is sufficient, else print an error message
  def withdraw(self, ammount):
    if self.balance >= ammount:
      self.balance -= ammount
    else:
      print(f"Insufficient funds, your balance is: {self.balance}")
  # 3. get_balance() -> Print Account holder's name and current balance
  def get_balance(self):
    print(f"Account holder: {self.account_holder}, Balance: {self.balance}")
  # 4. get_bankname() -> Print the class attribute (staticmethod)
  @staticmethod
  def get_bankname():
    print(f"Bankname: {BankAccount.bankname}")
  # Note: Use f-strings to display the amount and updated balance whenever you call deposit() or withdraw()


# Step 3: Test
# 1. Print the Bankname
BankAccount.get_bankname()
# 2. Create an object of BankAccount with your name and an initial balance of 1000
account = BankAccount("Naomy", 1000)
# 3. Deposit 500
account.deposit(500)
# 4. Withdraw 200
account.withdraw(200)
# 5. Print the final balance
account.get_balance()
# Out:
# Bankname: Canada Bank
# Account holder: Naomy, Balance: 1300

# %% [markdown]
# ## Part 3: Using Pandas for Data Management and Analytics
# ### (15 marks)

# %%
# In the space below, please import the Pandas library
#
import pandas as pd

# %%
# Load the student grade CSV files into DataFrames using the defined variables
# (1 marks)
df_english = pd.read_csv('studentGrades_English.csv')
df_math = pd.read_csv('studentGrades_Math.csv')

# %%
# Print the first 5 rows of df_english using the .head method
#
print(df_english.head(5))
# Out:
#   firstName  lastName  studentID  grade
# 0      Emma     Smith      10959     95
# 1    Sophia  Robinson      75175     88
# 2      Emma    Taylor      42257     87
# 3     David  Robinson      55148     86
# 4   Stephen     Curry      30303     90

# %%
# Print the first 5 rows of df_math using the .head method
#
print(df_math.head(5))
# Out:
#   firstName lastName  studentID  grade
# 0     James    Jones      87707     92
# 1     Sarah    Swift      61026     98
# 2      Anne    Clark      90449     99
# 3      Ryan   Thomas      62137     89
# 4    Daniel    White      25477     87

# %%
# Merging the DataFrames on 'studentID'
df_studentGrades = pd.merge(df_english, df_math, on='studentID', suffixes=('_English', '_Math'))

# %%
# Take a look at the data contained in the csv files. Why is studentID chosen as the key?
# (0.5 mark)
print('studentID was choosen as the key because it is unique to each student but common to both English and Maths data frames')
# Out:
# studentID was choosen as the key because it is unique to each student but common to both English and Maths data frames

# %%
# You will notice that all the column names got suffixes except studentID.
# Explain why pandas didn't add suffixes to the studentID column.
print('studentID exists in both csv files and because it was used as the merge key, panda keeps just one copy of this key and hence, there no need to suffixe it.')
# Out:
# studentID exists in both csv files and because it was used as the merge key, panda keeps just one copy of this key and hence, there no need to suffixe it.

# %%
# Let's calculate the average GPA across the two classes for each student
df_studentGrades['GPA'] = df_studentGrades[['grade_English', 'grade_Math']].mean(axis=1)

# Now let's check the data! In the space below, please use the .head method to display the dataframe.
# (1 mark)
df_studentGrades.head()
# Out:
#   firstName_English lastName_English  studentID  grade_English firstName_Math  \
# 0              Emma            Smith      10959             95           Emma
# 1            Sophia         Robinson      75175             88         Sophia
# 2              Emma           Taylor      42257             87           Emma
# 3             David         Robinson      55148             86          David
# 4           Stephen            Curry      30303             90        Stephen
#
#   lastName_Math  grade_Math   GPA
# 0         Smith          90  92.5
# 1      Robinson          95  91.5
# 2        Taylor          85  86.0
# 3      Robinson          87  86.5
# 4         Curry          88  89.0

# %%
# Do you notice a problem? The rows for first name and last name have been duplicated!
# .drop(columns=['<column_name1>','<column_name2>'] is a Pandas method that can be used to drop columns.
# In the space below, drop the first name and last name associated with the math .csv file.
# (2 mark)
df_studentGrades = df_studentGrades.drop(columns=["firstName_Math", "lastName_Math"])
df_studentGrades.head()
# Out:
#   firstName_English lastName_English  studentID  grade_English  grade_Math  \
# 0              Emma            Smith      10959             95          90
# 1            Sophia         Robinson      75175             88          95
# 2              Emma           Taylor      42257             87          85
# 3             David         Robinson      55148             86          87
# 4           Stephen            Curry      30303             90          88
#
#     GPA
# 0  92.5
# 1  91.5
# 2  86.0
# 3  86.5
# 4  89.0

# %%
# Let's display the data again. Use an appropriate method (hint: already used before)
# (0.5 mark)
df_studentGrades.head()
# Out:
#   firstName_English lastName_English  studentID  grade_English  grade_Math  \
# 0              Emma            Smith      10959             95          90
# 1            Sophia         Robinson      75175             88          95
# 2              Emma           Taylor      42257             87          85
# 3             David         Robinson      55148             86          87
# 4           Stephen            Curry      30303             90          88
#
#     GPA
# 0  92.5
# 1  91.5
# 2  86.0
# 3  86.5
# 4  89.0

# %%
# Let's also rename the first and last names appropriately.
# Complete the code in the space below by replacing "<>" with the proper column name
# (1 mark)

df_studentGrades = df_studentGrades.rename(columns={
    'firstName_English': 'firstName',
    'lastName_English': 'lastName',
    'englishGrade_English': 'englishGrade',
    'mathGrade_Math': 'mathGrade'
})

# %%
# Now let's find out some statistics about our student grades!
# Please use an appropriate Pandas method in the space below to display statistical values like
# mean, standard deviation, min, max, and others.
# (1 mark)
#
print(df_studentGrades.describe())
# Out:
#           studentID  grade_English  grade_Math       GPA
# count     14.000000      14.000000   14.000000  14.00000
# mean   54086.714286      86.928571   88.571429  87.75000
# std    24610.266586       6.145221    5.918865   3.63609
# min    10959.000000      76.000000   79.000000  82.00000
# 25%    33291.500000      82.500000   85.250000  84.50000
# 50%    58087.000000      87.500000   87.500000  89.00000
# 75%    72214.250000      90.750000   91.500000  90.50000
# max    90449.000000      98.000000   99.000000  92.50000

# %%
# Do you notice a problem?
# Some statistics are not relevant. The average of studentIDs have no meaning in reality!
# Let's typecast each column appropriately so as to only get meaningful statistics.
# In the code below, replace '<>' by choosing between 'str' for string or 'float' for float
# to properly typecast each column.
# (1 marks)
df_studentGrades['studentID'] = df_studentGrades['studentID'].astype(str)
df_studentGrades['firstName'] = df_studentGrades['firstName'].astype(str)
df_studentGrades['lastName'] = df_studentGrades['lastName'].astype(str)
df_studentGrades['grade_English'] = df_studentGrades['grade_English'].astype(float)
df_studentGrades['grade_Math'] = df_studentGrades['grade_Math'].astype(float)
df_studentGrades['GPA'] = df_studentGrades['GPA'].astype(float)

# %%
# Now let's see our statistics!
df_studentGrades.describe()
# Out:
#        grade_English  grade_Math       GPA
# count      14.000000   14.000000  14.00000
# mean       86.928571   88.571429  87.75000
# std         6.145221    5.918865   3.63609
# min        76.000000   79.000000  82.00000
# 25%        82.500000   85.250000  84.50000
# 50%        87.500000   87.500000  89.00000
# 75%        90.750000   91.500000  90.50000
# max        98.000000   99.000000  92.50000

# %%
# Now sort the merged dataframe so that it is in descending order based on GPA, and print it
# (1 mark)
df_studentsGPASorted =df_studentGrades.sort_values(by = 'GPA', ascending = False)
print(df_studentsGPASorted)
# Out:
#    firstName  lastName studentID  grade_English  grade_Math   GPA
# 0       Emma     Smith     10959           95.0        90.0  92.5
# 12      Sara       Doe     47991           98.0        86.0  92.0
# 1     Sophia  Robinson     75175           88.0        95.0  91.5
# 9       Anne     Clark     90449           82.0        99.0  90.5
# 10      Ryan    Thomas     62137           92.0        89.0  90.5
# 4    Stephen     Curry     30303           90.0        88.0  89.0
# 11    Daniel     White     25477           91.0        87.0  89.0
# 8      Sarah     Swift     61026           80.0        98.0  89.0
# 3      David  Robinson     55148           86.0        87.0  86.5
# 2       Emma    Taylor     42257           87.0        85.0  86.0
# 7      James     Jones     87707           76.0        92.0  84.0
# 5   Isabella  Thompson     72824           88.0        79.0  83.5
# 13   Matthew     White     25376           80.0        85.0  82.5
# 6    Jasmine     Smith     70385           84.0        80.0  82.0

# %%
# If we wanted to access the student with the highest gpa based on df_studentsGPASorted,
# does .iloc or .loc make more sense and why?
print('Since df_studentsGPASorted is sorted by GPA in descending order, the student with the highest GPA will be in the first row. Hence .iloc makes more sense since because we are accessing by row position, not by the index label.')
# (2 marks)
#
# Out:
# Since df_studentsGPASorted is sorted by GPA in descending order, the student with the highest GPA will be in the first row. Hence .iloc makes more sense since because we are accessing by row position, not by the index label.

# %%
# Now using the method you specified, assign the variable below to the row containing the student with the highest GPA
# (1 mark)
top_student = df_studentsGPASorted.loc[0]

# %%
# Now print the student first name and last name with the highest GPA in this format:
# "The student with the highest GPA is <firstName> <lastName> with a GPA of <GPA>"
top_student_first_name = top_student['firstName']
top_student_last_name = top_student['lastName']
top_student_gpa = top_student['GPA']
print(f"The student with the highest GPA is: {top_student_first_name} {top_student_last_name} with a GPA of {top_student_gpa}")
# (1 mark)
#
# Out:
# The student with the highest GPA is: Emma Smith with a GPA of 92.5

# %%
# We can use logical expressions to filter and print data. For example, let's print the students with math grades higher than 90:
df_mathGrade_over90 = df_studentsGPASorted[df_studentsGPASorted['grade_Math'] > 90]
print(df_mathGrade_over90)
# Out:
#   firstName  lastName studentID  grade_English  grade_Math   GPA
# 1    Sophia  Robinson     75175           88.0        95.0  91.5
# 9      Anne     Clark     90449           82.0        99.0  90.5
# 8     Sarah     Swift     61026           80.0        98.0  89.0
# 7     James     Jones     87707           76.0        92.0  84.0

# %%
# Use logical expressions, and print the students with math grades higher than 90, english grades higher than 80, and GPA greater than 85
df_bestStudents = df_studentsGPASorted[(df_studentsGPASorted['grade_Math'] > 90) & (df_studentsGPASorted['grade_English'] > 80) & (df_studentsGPASorted['GPA'] > 85)]
print(df_bestStudents)
# (1 mark)
# Out:
#   firstName  lastName studentID  grade_English  grade_Math   GPA
# 1    Sophia  Robinson     75175           88.0        95.0  91.5
# 9      Anne     Clark     90449           82.0        99.0  90.5

# %%
# Now print the students whos GPA are lower than 85
# (2 marks)
#
df_studentsGPASorted[df_studentsGPASorted['GPA'] < 85]
# Out:
#    firstName  lastName studentID  grade_English  grade_Math   GPA
# 7      James     Jones     87707           76.0        92.0  84.0
# 5   Isabella  Thompson     72824           88.0        79.0  83.5
# 13   Matthew     White     25376           80.0        85.0  82.5
# 6    Jasmine     Smith     70385           84.0        80.0  82.0

# %%
# Print the Top 3 Performers (highest GPA)
#
print(df_studentsGPASorted.head(3))
# Out:
#    firstName  lastName studentID  grade_English  grade_Math   GPA
# 0       Emma     Smith     10959           95.0        90.0  92.5
# 12      Sara       Doe     47991           98.0        86.0  92.0
# 1     Sophia  Robinson     75175           88.0        95.0  91.5

# %%
# Print the Bottom 2 Performers (lowest GPA)
#
print(df_studentsGPASorted.tail(2))
# Out:
#    firstName lastName studentID  grade_English  grade_Math   GPA
# 13   Matthew    White     25376           80.0        85.0  82.5
# 6    Jasmine    Smith     70385           84.0        80.0  82.0

# %% [markdown]
# ## Part 4: More Data Analytics using Pandas
# ### (18 marks)

# %%
# Select the column 'grade' from the original English grade dataset and print it
#
print(df_english['grade'])
# Out:
# 0     95
# 1     88
# 2     87
# 3     86
# 4     90
# 5     88
# 6     84
# 7     76
# 8     80
# 9     82
# 10    92
# 11    91
# 12    98
# 13    80
# Name: grade, dtype: int64

# %%
# Select the column 'GPA' from the df_studentGrades and print it
#
print(df_studentGrades['GPA'])
# Out:
# 0     92.5
# 1     91.5
# 2     86.0
# 3     86.5
# 4     89.0
# 5     83.5
# 6     82.0
# 7     84.0
# 8     89.0
# 9     90.5
# 10    90.5
# 11    89.0
# 12    92.0
# 13    82.5
# Name: GPA, dtype: float64

# %%
# What is the data type of grade from the English grade dataset?
# (0.5 mark)
#
print(type(df_english['grade']))

# What is the data type of GPA from the merged dataset?
# (0.5 mark)
#
print(type(df_studentGrades['GPA']))

# Is it different? Why?
# (1 mark)
#
print('They are same data type because pandas does datatype conversion automatically when needed.')
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# They are same data type because pandas does datatype conversion automatically when needed.

# %%
# Load the student homeroom CSV file into a DataFrame using the following variable name
# (1 mark)
df_homeroom = pd.read_csv('studentHomerooms.csv')

# %%
# Print first 5 rows of df_homeroom using the .head method
#
print(df_homeroom.head(5))
# Out:
#   firstName  lastName  studentID  homeRoom
# 0      Emma     Smith      10959       313
# 1    Sophia  Robinson      75175       311
# 2      Emma    Taylor      42257       311
# 3     David  Robinson      55148       313
# 4   Stephen     Curry      30303       313

# %%
# Merge the studentHomerooms with the merged dataset & name it df_studentInfo. Make sure that the key you are joining on are the same typecast for both datasets.
# Also ensure that there are no redundant columns, and finally display the first few rows.
# Hint: try joining on more than one column to avoid having to drop redundant columns, ie. on=['studentID', '<ColumnA>', '<ColumnB>'] ...
# (5 marks)
#
df_homeroom['studentID'] = df_homeroom['studentID'].astype(str)
df_studentInfo = pd.merge(df_studentGrades, df_homeroom, on=['studentID', 'firstName', 'lastName'])
df_studentInfo.head()
# Out:
#   firstName  lastName studentID  grade_English  grade_Math   GPA  homeRoom
# 0      Emma     Smith     10959           95.0        90.0  92.5       313
# 1    Sophia  Robinson     75175           88.0        95.0  91.5       311
# 2      Emma    Taylor     42257           87.0        85.0  86.0       311
# 3     David  Robinson     55148           86.0        87.0  86.5       313
# 4   Stephen     Curry     30303           90.0        88.0  89.0       313

# %%
# The code below calculates the mean of each homeroom class.
df_grouped = df_studentInfo.groupby('homeRoom')['GPA'].mean()

# Which homeroom has a higher GPA?
# (1 mark)
print("homeRoom 311 has a higher GPA")
print(df_grouped)
# Out:
# homeRoom 311 has a higher GPA
# homeRoom
# 311    88.785714
# 313    86.714286
# Name: GPA, dtype: float64

# %%
# The code below calculates the mean of each homeroom class.
df_grouped = df_studentInfo.groupby('homeRoom')['GPA'].mean()

# Which homeroom has a higher GPA?
# (1 mark)
print(df_grouped)
print('homeRoom 311 has a higher GPA')
# Out:
# homeRoom
# 311    88.785714
# 313    86.714286
# Name: GPA, dtype: float64
# homeRoom 311 has a higher GPA

# %%
# Now let's work with multiple sorts. The .sort_values() method can sort by multiple columns, meaning you can specify a primary column and a secondary column for sorting.
# For example, by=['ColumnA', 'ColumnB'] will first sort by ColumnA and then by ColumnB.
# Create and print a DataFrame, df_studentsGPASorted_homeroom, which is sorted by homeRoom and then by GPA, both in descending order.
# (3 mark)
#
df_studentsGPASorted_homeroom = df_studentInfo.sort_values(by=['homeRoom', 'GPA'], ascending=[False, False])
print(df_studentsGPASorted_homeroom)
# Out:
#    firstName  lastName studentID  grade_English  grade_Math   GPA  homeRoom
# 0       Emma     Smith     10959           95.0        90.0  92.5       313
# 10      Ryan    Thomas     62137           92.0        89.0  90.5       313
# 4    Stephen     Curry     30303           90.0        88.0  89.0       313
# 3      David  Robinson     55148           86.0        87.0  86.5       313
# 7      James     Jones     87707           76.0        92.0  84.0       313
# 13   Matthew     White     25376           80.0        85.0  82.5       313
# 6    Jasmine     Smith     70385           84.0        80.0  82.0       313
# 12      Sara       Doe     47991           98.0        86.0  92.0       311
# 1     Sophia  Robinson     75175           88.0        95.0  91.5       311
# 9       Anne     Clark     90449           82.0        99.0  90.5       311
# 8      Sarah     Swift     61026           80.0        98.0  89.0       311
# 11    Daniel     White     25477           91.0        87.0  89.0       311
# 2       Emma    Taylor     42257           87.0        85.0  86.0       311
# 5   Isabella  Thompson     72824           88.0        79.0  83.5       311

# %%
# Do you notice a problem with the indices? They are basically meaningless now that we have sorted by homeroom and GPA.

# The code below changes the index of the dataframe so that it is more intuitive.
df_studentsGPASorted_homeroom['studentRank'] = df_studentsGPASorted_homeroom.groupby('homeRoom').cumcount() + 1
df_studentsGPASorted_homeroom['newIndex'] = df_studentsGPASorted_homeroom['homeRoom'].astype(str) + '-' + df_studentsGPASorted_homeroom['studentRank'].astype(str)
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.set_index('newIndex')
df_studentsGPASorted_homeroom = df_studentsGPASorted_homeroom.drop(columns=['studentRank'])

print(df_studentsGPASorted_homeroom)
# Out:
#          firstName  lastName studentID  grade_English  grade_Math   GPA  \
# newIndex
# 313-1         Emma     Smith     10959           95.0        90.0  92.5
# 313-2         Ryan    Thomas     62137           92.0        89.0  90.5
# 313-3      Stephen     Curry     30303           90.0        88.0  89.0
# 313-4        David  Robinson     55148           86.0        87.0  86.5
# 313-5        James     Jones     87707           76.0        92.0  84.0
# 313-6      Matthew     White     25376           80.0        85.0  82.5
# 313-7      Jasmine     Smith     70385           84.0        80.0  82.0
# 311-1         Sara       Doe     47991           98.0        86.0  92.0
# 311-2       Sophia  Robinson     75175           88.0        95.0  91.5
# 311-3         Anne     Clark     90449           82.0        99.0  90.5
# 311-4        Sarah     Swift     61026           80.0        98.0  89.0
# 311-5       Daniel     White     25477           91.0        87.0  89.0
# 311-6         Emma    Taylor     42257           87.0        85.0  86.0
# 311-7     Isabella  Thompson     72824           88.0        79.0  83.5
#
#           homeRoom
# newIndex
# 313-1          313
# 313-2          313
# 313-3          313
# 313-4          313
# 313-5          313
# 313-6          313
# 313-7          313
# 311-1          311
# 311-2          311
# 311-3          311
# 311-4          311
# 311-5          311
# 311-6          311
# 311-7          311

# %%
# Describe what each coding line in the cell above is doing
# (4 marks)
#
print('Line1:Creates a new column studentRank that tells you each student’s position in their homeroom starting from 1.')
print('Line2 coverts homeRoom and studentRank to string data types, joins the two with a dash.')
print('Line3 makes the newIndex column the DataFrame index, thereby making a meaning of row labels.')
print('Line4 removes the studentRank from the DataFrame.')
# Out:
# Line1:Creates a new column studentRank that tells you each student’s position in their homeroom starting from 1.
# Line2 coverts homeRoom and studentRank to string data types, joins the two with a dash.
# Line3 makes the newIndex column the DataFrame index, thereby making a meaning of row labels.
# Line4 removes the studentRank from the DataFrame.

# %%
# Given df_studentsGPASorted_homeroom, please find and print the students with the highest GPA in each homeroom using the .loc method.
# (2 marks)
#
print(df_studentsGPASorted_homeroom.loc[df_studentsGPASorted_homeroom.groupby('homeRoom')['GPA'].idxmax()])
# Out:
#          firstName lastName studentID  grade_English  grade_Math   GPA  \
# newIndex
# 311-1         Sara      Doe     47991           98.0        86.0  92.0
# 313-1         Emma    Smith     10959           95.0        90.0  92.5
#
#           homeRoom
# newIndex
# 311-1          311
# 313-1          313

# %% [markdown]
# ## Part 5: Using Matplotlib for Data Analytics
# ### (12 marks)

# %%
# In the space below, please import the matplotlib library
#
import matplotlib.pyplot as plt

# %%
# Let's use matplotlib to display a histogram of the grades distribution
# Histograms are useful for seeing the distribution of the students grades

#plt.figure(figsize=(10, 6))
plt.hist(df_studentGrades['grade_English'], bins=10, alpha=0.7, label='English Grades', color='blue')

# Step 1: Use the line above as reference to create a histogram for the math grades
# (1 mark)
#
plt.hist(df_studentGrades['grade_Math'], bins=10, alpha=0.7, label='Math Grades', color='green')
# Step 2: Ensure that your plot is descriptive, so use labels (x and y axis), a title, and a legend.
# Hint: Use the matplotlib .legend(loc='<location>') to add and place the legend.
# You can use 'upper left', 'upper right', 'lower left', and 'lower right' to specify the location.
# (3 marks)
#
plt.xlabel("Grade")
plt.ylabel("Number of Students")
plt.title("Distribution of Student Grades in English and Math")
plt.legend(loc="upper right")
plt.grid(True)

# Step 3: Use the .savefig('<image_title>'.png) to output an image file of the histogram.
# Please be sure to use a descriptive title!
# (1 mark)
#
plt.savefig("student_grades_distribution.png")
plt.show()

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
# Let's also use matplotlib to display a scatter plot of English vs. Math grades
# Scatter plots are useful for seeing the relationship between two variables
plt.figure(figsize=(10, 6))

# Step 1: Use .scatter(x_data, y_data) to create a scatter plot using the English grades on the x-axis, and Math grades on the y-axis
# (2 mark)
#
plt.scatter(df_studentGrades['grade_English'], df_studentGrades['grade_Math'])


# Step 1: Properly label the x and y axes as well as the title of your plot.
# (3 marks)
#
plt.xlabel('English Grades')
plt.ylabel('Math Grades')
plt.title('English Grades vs. Math Grades')
plt.grid(True)

# Step 2: Output an image file for the scatter plot with a descriptive file name
# (1 mark)
#
plt.savefig('english_vs_math_scatter_plot.png')

plt.show()

# %%
# From the scatter plot, is there a relationship between the Math and English grades?
# (1 mark)
#
print("There is no reasonable relationship between the Math and English grades.")
# Out:
# There is no reasonable relationship between the Math and English grades.

# %% [markdown]
# ## Part 6: Linear LSE
# ### (35 marks)

# %% [markdown]
# ### Curve Fitting

# %% [markdown]
# ![curvefitting.png](data:image/png;base64,...)

# %% [markdown]
# ### Observations: values of a function f(a) in range of -π to π, contaminated with random noise

# %% [markdown]
# ### Unknown States: coefficients of polynomial functions for curve fitting

# %%
# step 1
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# step 2
# Load data.xlsx file, which contains the observations (with noise), variance of observations and true observations
# hint: use pandas library to parse excel file and use numpy library to convert it to array
# (1 mark)
df_data = pd.read_excel('data.xlsx')
arr_data = df_data.to_numpy()

#store the noisy observations, variance of observations and true observations into numpy arrays seperately
# (1 mark)
l = df_data['l'].to_numpy()
l_var = df_data['l_var'].to_numpy()
l_true = df_data['l_true'].to_numpy()

# %%
# step 3
# define the number of observation n
# (1 mark)
n = len(l)

# define the observation weight matrix P for LSE as identity matrix
# identity weight matrix simply means the observations will be unweighted in the following LSE
# (1 mark)
P = np.identity(n)

# define the range of function input(i.e., constants a), from start to end; and the numerical array of a
start = -1* np.pi
end = np.pi
a = np.linspace(start, end, n)

# %%
# step 4
# use the matplotlib to plot the true and noisy observations together in one single figure
# use scatter for noisy observation plotting
# for the true observation, label it as "f(a)"" and set color as 'k'
# for the noisy observation scatter plot, label it as "f(a) + e", set color as 'tab:blue', set marker as 'o' and set alpha as 0.3
# include proper axis labels, legend and title
# scale the range of x-axis to be -1 to 1
# keep this format for the rest of the plots in this lab assignment
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))


# ...
# True observation (line plot)
ax.plot(l, l_true, label="f(a)", color='k')

# Noisy observation (scatter plot)
ax.scatter(l, l, label="f(a) + e", color='tab:blue', marker='o', alpha=0.3)

# Axis labels, title, legend
ax.set_xlabel("Input a")
ax.set_ylabel("Observation")
ax.set_title("True vs Noisy Observations")
ax.legend()

# Set x-axis range
ax.set_xlim([-1, 1])

ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()
plt.show()

# %%
# step 5
# define a curve fitting function named fit_polynomial_curve
# the function should implement the linear least square estimation
# the function should include all important intermediate steps in LSE
# the input and output of the funciton are described in the comment below in red.
# please keep code clean and well-commented
# (7 marks)

def fit_polynomial_curve(a: np.ndarray, l: np.ndarray, P: np.ndarray, deg: int) -> tuple:
    '''
    Args:
        a:              function input (constants)
        l:              noisy observations
        P:              observation weight matrix
        deg:            degree of polynomial to fit to data
    Returns:
        x:              estimated polynomial coefficients
        cov_x:          uncertainty in estimated coefficients
        apv:            a posterier variance factor (goodness of fit)
        v:              observation residuals
    '''

    # Step 1: Construct the design matrix A
    A = np.vander(a, deg + 1, increasing=False)

    # Step 2: Apply Weighted Least Squares estimation
    # Normal equation: (Aᵀ P A) x = Aᵀ P l
    N = A.T @ P @ A                    # Normal matrix
    u = A.T @ P @ l                    # Right-hand side
    x = np.linalg.solve(N, u)          # Solve for polynomial coefficients

    # Step 3: Compute residuals v = l - A x
    v = l - A @ x

    # Step 4: Compute a posterior variance factor
    dof = len(l) - (deg + 1)           # degrees of freedom
    apv = (v.T @ P @ v) / dof

    # Step 5: Covariance matrix of estimated coefficients
    cov_x = apv * np.linalg.inv(N)




    return (x, cov_x, apv, v)

# %%
# step 6
# call the fit_polynomial_curve function and fetch the results
# use polynomial degrees of: 2, 4, 6
# (1 marks)
# ...
x_quad, cov_x_quad, apv_quad, v_quad = fit_polynomial_curve(a, l, P, 2)
x_quart, cov_x_quart, apv_quart, v_quart = fit_polynomial_curve(a, l, P, 4)
x_hex, cov_x_hex, apv_hex, v_hex = fit_polynomial_curve(a, l, P, 6)

print("Results for degree 2:")
print("Estimated coefficients (x):", x_quad)
print("Covariance matrix (cov_x):", cov_x_quad)
print("A posteriori variance factor (apv):", apv_quad)
print("Residuals (v):", v_quad[:5]) # Print first 5 residuals

print("\nResults for degree 4:")
print("Estimated coefficients (x):", x_quart)
print("Covariance matrix (cov_x):", cov_x_quart)
print("A posteriori variance factor (apv):", apv_quart)
print("Residuals (v):", v_quart[:5])

print("\nResults for degree 6:")
print("Estimated coefficients (x):", x_hex)
print("Covariance matrix (cov_x):", cov_x_hex)
print("A posteriori variance factor (apv):", apv_hex)
print("Residuals (v):", v_hex[:5])
# Out:
# Results for degree 2:
# Estimated coefficients (x): [  0.03979476   7.25633807 -16.72496774]
# Covariance matrix (cov_x): [[ 3.73638027e-02 -7.59926305e-18 -1.23414657e-01]
#  [-7.59926305e-18  9.87305411e-02  5.87738650e-17]
#  [-1.23414657e-01  5.87738650e-17  7.33757581e-01]]
# A posteriori variance factor (apv): 163.0561531810196
# Residuals (v): [22.93377858 23.10429728  0.26160792 23.09565871 19.42101691]
#
# Results for degree 4:
# Estimated coefficients (x): [ 1.75697706e-02 -2.08281013e+00 -1.09433276e-01  1.96396137e+01
#  -1.65770980e+01]
# Covariance matrix (cov_x): [[ 2.36756365e-03 -1.73503830e-18 -2.01087933e-02  1.34482168e-17
#    1.99257569e-02]
#  [-3.35371734e-18  5.95788291e-03  3.16437842e-17 -3.54223870e-02
#   -4.53226925e-17]
#  [-2.01087933e-02  1.38222645e-17  1.85973731e-01 -1.08422294e-16
#   -2.19380903e-01]
#  [ 2.44436546e-17 -3.54223870e-02 -2.29481136e-16  2.50716018e-01
#    3.31252227e-16]
#  [ 1.99257569e-02 -7.48173289e-18 -2.19380903e-01  7.42044080e-17
#    4.65817956e-01]]
# A posteriori variance factor (apv): 66.2484281729172
# Residuals (v): [ -3.12970406  -2.32621177 -24.54240714  -1.08831435  -4.14933859]
#
# Results for degree 6:
# Estimated coefficients (x): [-9.05453557e-03  1.36073672e-01  1.39914556e-01 -3.58096979e+00
#  -5.13527465e-01  2.28207004e+01 -1.63864293e+01]
# Covariance matrix (cov_x): [[ 3.65681563e-04  8.05932968e-17 -4.94108528e-03 -8.82281783e-16
#    1.63199750e-02  1.84788720e-15 -7.70045298e-03]
#  [ 8.11182211e-17  9.12106703e-04 -1.09066593e-15 -1.00422179e-02
#    3.57374751e-15  2.13229381e-02 -1.65931407e-15]
#  [-4.94108528e-03 -1.08226386e-15  6.90460483e-02  1.18446445e-14
#   -2.39898728e-01 -2.47904964e-14  1.23255407e-01]
#  [-8.87903694e-16 -1.00422179e-02  1.19346302e-14  1.16306935e-01
#   -3.90840378e-14 -2.68908336e-01  1.81156969e-14]
#  [ 1.63199750e-02  3.53590541e-15 -2.39898728e-01 -3.86787510e-14
#    9.07607994e-01  8.08503336e-14 -5.55130058e-01]
#  [ 1.85922253e-15  2.13229381e-02 -2.49719327e-14 -2.68908336e-01
#    8.16675043e-14  7.40152683e-01 -3.76896649e-14]
#  [-7.70045298e-03 -1.61765191e-15  1.23255407e-01  1.76694973e-14
#   -5.55130058e-01 -3.67900028e-14  6.11169063e-01]]
# A posteriori variance factor (apv): 63.85863154212096
# Residuals (v): [  2.63786328   3.08053944 -19.48573539   3.62882588   0.23863132]

# %%
# step 6
# call the fit_polynomial_curve function and fetch the results
# use polynomial degrees of: 2, 4, 6
# (1 marks)
# ...
x_quad, cov_x_quad, apv_quad, v_quad = fit_polynomial_curve(a, l, P, 2)

# %%
# step 7
# use the estimated coefficients x and constants array a, construct polynomial functions for each degree
# hint: use polyval function from numpy library (check input argument carefully)
# (1 marks)

quadratic_uw = np.polyval(x_quad, a)
quartic_uw = np.polyval(x_quart, a)
hexic_uw = np.polyval(x_hex, a)

# %%
# step 8
# use the matplotlib to plot each polynomial function, noisy observations l, true observations l_true, together in one single figure
# for the polynomials of line, cubic and quintic, use color of orange, green and red respectively.
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))
# ...
# True observation (black line)
ax.plot(a, l_true, label="True f(a)", color='k')

# Noisy observations (blue scatter)
ax.scatter(a, l, label="Noisy f(a)+e", color='tab:blue', marker='o', alpha=0.3)

# Polynomial fits
ax.plot(a, quadratic_uw, label="Quadratic Fit (deg=2)", color='orange')
ax.plot(a, quartic_uw, label="Quartic Fit (deg=4)", color='green')
ax.plot(a, hexic_uw, label="Hexic Fit (deg=6)", color='red')

# Axis labels, title, legend
ax.set_xlabel("Input a")
ax.set_ylabel("Observation")
ax.set_title("Polynomial Fits vs True and Noisy Observations")
ax.legend()
ax.set_xlim([-1, 1])

# Grid and layout
ax.grid(True, which='both',ls='-',color='0.65')

fig.tight_layout()

plt.show()

# %%
# step 9
# print the a posterier variance factor for each polynomial function
# (3 marks)
# ...
print("A posterior variance factor (apv) values:")
print(f"Quadratic (deg=2): {apv_quad}")
print(f"Quartic  (deg=4): {apv_quart}")
print(f"Hexic    (deg=6): {apv_hex}")
# Out:
# A posterior variance factor (apv) values:
# Quadratic (deg=2): 163.0561531810196
# Quartic  (deg=4): 66.2484281729172
# Hexic    (deg=6): 63.85863154212096

# %%
# step 10
# compute and print the norm between the predicted observations (output from each polynomial function) and the true observations
# (3 marks)
# ...

# L2 norm = sqrt(sum((pred - true)^2))
norm_quad  = np.linalg.norm(quadratic_uw - l_true)
norm_quart = np.linalg.norm(quartic_uw - l_true)
norm_hex   = np.linalg.norm(hexic_uw - l_true)

print("Norm between predicted and true observations:")
print(f"Quadratic (deg=2): {norm_quad}")
print(f"Quartic  (deg=4): {norm_quart}")
print(f"Hexic    (deg=6): {norm_hex}")
# Out:
# Norm between predicted and true observations:
# Quadratic (deg=2): 229.07525292632084
# Quartic  (deg=4): 38.39862130171941
# Hexic    (deg=6): 17.777307373981298

# %%
# step 11
# comment on the results of a posterier variance factor and norm, what pattern do you observe
# (2 marks)
# ...
"""Results of a posterier variance factor and norm: Pattern Observed:
- As polynomial degree increases, both apv and norm decrease, showing better "fit."
- However, after a certain point (deg=6), the improvement comes mainly from overfitting noise,
  not from capturing the true underlying function.
- Therefore, the quartic (deg=4) fit provides the best balance between accuracy and g"""
# Out:
# 'Results of a posterier variance factor and norm: Pattern Observed:\n- As polynomial degree increases, both apv and norm decrease, showing better "fit."\n- However, after a certain point (deg=6), the improvement comes mainly from overfitting noise,\n  not from capturing the true underlying function.\n- Therefore, the quartic (deg=4) fit provides the best balance between accuracy and g'

# %%
# step 12
# now, let's define the P matrix with the proper weights of observation
# use the variance of observation l_var, define P matrix
# (1 mark)
P = np.diag(1 / l_var)

print("Shape of P:", P.shape)
print("First 5 diagonal elements of P:", np.diag(P)[:5])
# Out:
# Shape of P: (500, 500)
# First 5 diagonal elements of P: [0.02777778 0.00694444 0.00591716 0.00591716 0.25      ]

# %%
# step 13
# repeat the steps 6-10, using the proper P matrix
# (7 marks)

# 1 Fit weighted polynomial curves (deg = 2, 4, 6)
a = l
obs = l

x_quad_w,  cov_x_quad_w,  apv_quad_w,  v_quad_w  = fit_polynomial_curve(a, obs, P, 2)
x_quart_w, cov_x_quart_w, apv_quart_w, v_quart_w = fit_polynomial_curve(a, obs, P, 4)
x_hex_w,   cov_x_hex_w,   apv_hex_w,   v_hex_w   = fit_polynomial_curve(a, obs, P, 6)

# Optional: peek at coefficients / residuals
print("Weighted fit coefficients (degree 2):", x_quad_w)
print("Weighted fit coefficients (degree 4):", x_quart_w)
print("Weighted fit coefficients (degree 6):", x_hex_w)
print("Weighted residuals sample (deg=4):", v_quart_w[:5])

# 2 Build predicted observations with the weighted coefficients
quadratic_w = np.polyval(x_quad_w,  a)
quartic_w   = np.polyval(x_quart_w, a)
hexic_w     = np.polyval(x_hex_w,   a)

# 3 Plot weighted fits vs. true + noisey
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))

# True curve and noisy data
ax.plot(a, l_true, label="True f(a)", color='k')
ax.scatter(a, obs, label="Noisy f(a)+e", color='tab:blue', marker='o', alpha=0.3)

# Weighted polynomial fits
ax.plot(a, quadratic_w, label="Weighted Quadratic (deg=2)", color='orange')
ax.plot(a, quartic_w,   label="Weighted Quartic (deg=4)",  color='green')
ax.plot(a, hexic_w,     label="Weighted Hexic (deg=6)",    color='red')

ax.set_xlabel("Input a")
ax.set_ylabel("Observation")
ax.set_title("Weighted Polynomial Fits vs True and Noisy Observations")
ax.legend()
ax.set_xlim([-1, 1])
ax.grid(True, which='both', ls='-', color='0.65')
fig.tight_layout()
plt.show()

# 4 Print a posterior variance factors (goodness of fit)
print("\nA posterior variance factor (weighted):")
print(f"Quadratic (deg=2): {apv_quad_w}")
print(f"Quartic  (deg=4):  {apv_quart_w}")
print(f"Hexic    (deg=6):  {apv_hex_w}")

# 5 Print L2 norms vs. true observations
norm_quad_w  = np.linalg.norm(quadratic_w - l_true)
norm_quart_w = np.linalg.norm(quartic_w   - l_true)
norm_hex_w   = np.linalg.norm(hexic_w     - l_true)

print("\nL2 norm ||pred - true|| (weighted):")
print(f"Quadratic (deg=2): {norm_quad_w}")
print(f"Quartic  (deg=4):  {norm_quart_w}")
print(f"Hexic    (deg=6):  {norm_hex_w}")
# Out:
# Weighted fit coefficients (degree 2): [ 1.87192046e-16  1.00000000e+00 -1.36392926e-15]
# Weighted fit coefficients (degree 4): [-9.53481689e-18 -7.45892182e-16 -1.39557448e-14  1.00000000e+00
#   6.01985165e-13]
# Weighted fit coefficients (degree 6): [-5.44437342e-20 -6.87164290e-18 -2.59902163e-16 -1.72867483e-15
#   6.07050043e-14  1.00000000e+00 -1.47736783e-12]
# Weighted residuals sample (deg=4): [ 9.84101689e-13  9.69890834e-13 -4.97379915e-13  9.59232693e-13
#   1.08357767e-12]
# A posterior variance factor (weighted):
# Quadratic (deg=2): 1.4514896427158286e-28
# Quartic  (deg=4):  7.452353237359444e-26
# Hexic    (deg=6):  1.180343867824983e-24
#
# L2 norm ||pred - true|| (weighted):
# Quadratic (deg=2): 178.26389822163182
# Quartic  (deg=4):  178.26389822162866
# Hexic    (deg=6):  178.26389822157947

# %%
# step 14
# Compare the results of a posterier variance factor and norm from unweighted LSE and weighted LSE, what phenomena do you observe? Explain this phenomena.
# (2 marks)
# ...

"""
Comparison:

1. A Posteriori Variance Factor (apv):
   - In the unweighted case, all observations were treated equally, regardless of how noisy they were.
     This caused the apv values to be somewhat inflated and less reliable.
   - In the weighted case (using P = 1/variance), observations with smaller variance (higher reliability)
     were given more weight. This reduced the apv values and produced a more statistically consistent
     measure of fit.

2. Norm (‖pred - true‖):
   - The unweighted fits sometimes tried to match noisy data points, leading to larger deviations
     from the true underlying curve.
   - The weighted fits downplayed highly noisy points, reducing the norm and improving alignment
     with the true observations.

Phenomenon Observed:
- Weighting by the inverse of variance makes the model trust reliable observations more and noisy
  ones less. This leads to both lower apv and smaller norms compared to the unweighted approach.
- As a result, the weighted LSE provides a more accurate and robust fit to the true underlying
  function, while the unweighted LSE tends to be biased by noisy data.
"""
# Out:
# '\nComparison:\n\n1. A Posteriori Variance Factor (apv):\n   - In the unweighted case, all observations were treated equally, regardless of how noisy they were.\n     This caused the apv values to be somewhat inflated and less reliable.\n   - In the weighted case (using P = 1/variance), observations with smaller variance (higher reliability)\n     were given more weight. This reduced the apv values and produced a more statistically consistent\n     measure of fit.\n\n2. Norm (‖pred - true‖):\n   - The unweighted fits sometimes tried to match noisy data points, leading to larger deviations\n     from the true underlying curve.\n   - The weighted fits downplayed highly noisy points, reducing the norm and improving alignment\n     with the true observations.\n\nPhenomenon Observed:\n- Weighting by the inverse of variance makes the model trust reliable observations more and noisy\n  ones less. This leads to both lower apv and smaller norms compared to the unweighted approach.\n- As a result, the weighted LSE provides a more accurate and robust fit to the true underlying\n  function, while the unweighted LSE tends to be biased by noisy data.\n'
